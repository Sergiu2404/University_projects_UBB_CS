# %%
import torch
import torchvision
import matplotlib.pyplot as plt
from PIL import Image

# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg')



# Create a grid of images
grid = torchvision.utils.make_grid(image)

# Display the grid using matplotlib
plt.imshow(grid.permute(1, 2, 0))
plt.show()

# %%
import numpy as np

# Load an image file into a Python array
image = Image.open('corgi.jpg')
image_array = np.array(image)

# Display the image using matplotlib
plt.imshow(image_array)
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 8)



images = torch.rand(10, 1, 28, 28)

# Build 6 conv. filters
conv_filters = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(3, 3), stride=1, padding=1)

# Convolve the image with the filters
output_feature = conv_filters(images)
print(output_feature.shape)
# Out:
# torch.Size([10, 6, 28, 28])

# %%
# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg').float()

# Normalize the pixel values to be between 0 and 1
image /= 255.0



# Define a convolutional filter with 3 input channels, 10 output channels, and a kernel size of 3
conv_filter = nn.Conv2d(3, 10, kernel_size=3)


print(image.shape)
# Out:
# torch.Size([3, 334, 515])

# %%
output = conv_filter(image)



# Create a grid of images
grid = torchvision.utils.make_grid(output)
# Display the grid using matplotlib
plt.imshow(output.detach()[2]) # One 0 is the batch and one is the signal (RGB)
plt.show()

#This is just 1 random filter

# %%
# Ex 1: Look at some other channels
import torchvision


# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg').float()

# Normalize the pixel values to be between 0 and 1
image /= 255.0

# Define a convolutional filter with 3 input channels, 100 output channels, and a kernel size of 3
conv_filter = nn.Conv2d(3, 100, kernel_size=3)

print(image.shape)

output = conv_filter(image)

# Create a grid of images
grid = torchvision.utils.make_grid(output)

# Display the grid using matplotlib
plt.imshow(output.detach()[2]) # One 0 is the batch and one is the signal (RGB)
plt.show()

#This is just 1 random filter
# Out:
# torch.Size([3, 334, 515])

# %%
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# Setup training data
train_data = datasets.FashionMNIST(
    root="data", # where to download data to?
    train=True, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=ToTensor(), # images come as PIL format, we want to turn into Torch tensors
    target_transform=None # you can transform labels as well
)

# Setup testing data
test_data = datasets.FashionMNIST(
    root="data",
    train=False, # get test data
    download=True,
    transform=ToTensor()
)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:01<00:00, 16375413.51it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 301643.72it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5610097.92it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 19900716.12it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
# See first training sample
image, label = train_data[0]
image, label
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %%
# See classes
class_names = train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#HW EX1
# Print the len of the train and test datasets
print(len(train_data))
print(len(test_data))
# Out:
# 60000
# 10000

# %%
import matplotlib.pyplot as plt
image, label = train_data[0]
print(f"Image shape: {image.shape}")
plt.imshow(image.squeeze()) # image shape is [1, 28, 28] (colour channels, height, width)
plt.title(label);
# Out:
# Image shape: torch.Size([1, 28, 28])

# %%
# HW EX3

# Access some random data from train_data
image, label = train_data[10]
print(f"Image shape: {image.shape}")
plt.imshow(image.squeeze()) # image shape is [1, 28, 28] (colour channels, height, width)
plt.title(label);
# Out:
# Image shape: torch.Size([1, 28, 28])

# %%
import torch
import matplotlib.pyplot as plt

torch.manual_seed(42)

fig = plt.figure(figsize=(9, 9))
rows, cols = 4, 4

for i in range(1, rows * cols + 1):
    random_idx = torch.randint(0, len(train_data), size=[1]).item()


    image, label = train_data[random_idx]

    # Plot the image
    fig.add_subplot(rows, cols, i)
    plt.imshow(image.squeeze(), cmap="gray")  # Assuming grayscale images
    plt.title(class_names[label])
    plt.axis(False)

plt.tight_layout()
plt.show()

# %%
from torch.utils.data import DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch?
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x7cfc5c89da20>, <torch.utils.data.dataloader.DataLoader object at 0x7cfc5c89c670>)
# Length of train dataloader: 1875 batches of 32
# Length of test dataloader: 313 batches of 32

# %%
# Check out what's inside the training dataloader
# This is how we get some random samples
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# (torch.Size([32, 1, 28, 28]), torch.Size([32]))

# %%
# EX 4 HW
# Use Flatten + 2x Linear layer for the base model
from torch import nn

class FashionMNISTModelV0(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        #EX 4 START HERE
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, output_shape)
        )
        #EX 4 END HERE
    def forward(self, x):
        return self.layer_stack(x)

# Assuming input image shape is (1, 28, 28) and there are 10 classes
input_shape = 1 * 28 * 28
hidden_units = 128
output_shape = 10

# Initialize the model
model = FashionMNISTModelV0(input_shape, hidden_units, output_shape)

# Print model architecture
print(model)
# Out:
# FashionMNISTModelV0(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
torch.manual_seed(42)

# Need to setup model with input parameters
model_0 = FashionMNISTModelV0(input_shape=784, # one for every pixel (28x28)
    hidden_units=10, # how many units in the hiden layer
    output_shape=len(class_names) # one for every class
)

# %%
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
# EX 5 HW
# Define the loss as Cross Entropy loss and the sgd optimizer
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_0.parameters(), lr=0.1)

# %%
from timeit import default_timer as timer
def print_train_time(start: float, end: float, device: torch.device = None):
    """Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format).
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
# EX 6 HW
#  Create a loss_values_arr and plot it after the training loop

# Start the training loop
num_epochs = 3
loss_values_arr = []
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_dataloader):
        # Move images and labels to device
        # images = images.to(device)
        # labels = labels.to(device)

        # Forward pass
        outputs = model_0(images)
        loss = loss_fn(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store the loss value
        loss_values_arr.append(loss.item())

        # Print the loss and accuracy every 100 iterations
        if (i+1) % 3 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_dataloader)}], Loss: {loss.item():.4f}")

# Plot the loss values
plt.plot(loss_values_arr)
plt.title("Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()
# Out:
# Epoch [1/3], Step [3/1875], Loss: 2.2577
# Epoch [1/3], Step [6/1875], Loss: 2.2076
# Epoch [1/3], Step [9/1875], Loss: 2.2435
# Epoch [1/3], Step [12/1875], Loss: 2.1228
# Epoch [1/3], Step [15/1875], Loss: 1.9975
# Epoch [1/3], Step [18/1875], Loss: 2.0929
# Epoch [1/3], Step [21/1875], Loss: 2.0475
# Epoch [1/3], Step [24/1875], Loss: 1.9852
# Epoch [1/3], Step [27/1875], Loss: 1.9655
# Epoch [1/3], Step [30/1875], Loss: 1.7469
# Epoch [1/3], Step [33/1875], Loss: 1.6684
# Epoch [1/3], Step [36/1875], Loss: 1.7418
# Epoch [1/3], Step [39/1875], Loss: 1.7651
# Epoch [1/3], Step [42/1875], Loss: 1.4508
# Epoch [1/3], Step [45/1875], Loss: 1.3927
# Epoch [1/3], Step [48/1875], Loss: 1.4384
# Epoch [1/3], Step [51/1875], Loss: 1.2901
# Epoch [1/3], Step [54/1875], Loss: 1.1645
# Epoch [1/3], Step [57/1875], Loss: 1.1040
# Epoch [1/3], Step [60/1875], Loss: 1.2475
# Epoch [1/3], Step [63/1875], Loss: 1.1611
# Epoch [1/3], Step [66/1875], Loss: 1.2757
# Epoch [1/3], Step [69/1875], Loss: 1.2607
# Epoch [1/3], Step [72/1875], Loss: 1.0138
# Epoch [1/3], Step [75/1875], Loss: 0.9963
# Epoch [1/3], Step [78/1875], Loss: 1.0980
# Epoch [1/3], Step [81/1875], Loss: 1.0581
# Epoch [1/3], Step [84/1875], Loss: 0.9138
# Epoch [1/3], Step [87/1875], Loss: 1.1827
# Epoch [1/3], Step [90/1875], Loss: 1.0064
# Epoch [1/3], Step [93/1875], Loss: 0.6775
# Epoch [1/3], Step [96/1875], Loss: 1.4143
# Epoch [1/3], Step [99/1875], Loss: 1.0268
# Epoch [1/3], Step [102/1875], Loss: 0.8476
# Epoch [1/3], Step [105/1875], Loss: 0.8754
# Epoch [1/3], Step [108/1875], Loss: 1.0960
# Epoch [1/3], Step [111/1875], Loss: 0.8691
# Epoch [1/3], Step [114/1875], Loss: 0.9981
# Epoch [1/3], Step [117/1875], Loss: 0.7637
# Epoch [1/3], Step [120/1875], Loss: 1.1717
# Epoch [1/3], Step [123/1875], Loss: 1.0547
# Epoch [1/3], Step [126/1875], Loss: 0.8548
# Epoch [1/3], Step [129/1875], Loss: 1.1030
# Epoch [1/3], Step [132/1875], Loss: 0.8693
# Epoch [1/3], Step [135/1875], Loss: 0.7770
# Epoch [1/3], Step [138/1875], Loss: 1.0740
# Epoch [1/3], Step [141/1875], Loss: 0.7103
# Epoch [1/3], Step [144/1875], Loss: 0.9397
# Epoch [1/3], Step [147/1875], Loss: 0.9001
# Epoch [1/3], Step [150/1875], Loss: 0.9964
# Epoch [1/3], Step [153/1875], Loss: 0.7611
# Epoch [1/3], Step [156/1875], Loss: 0.6522
# Epoch [1/3], Step [159/1875], Loss: 1.0348
# Epoch [1/3], Step [162/1875], Loss: 0.6764
# Epoch [1/3], Step [165/1875], Loss: 0.6551
# Epoch [1/3], Step [168/1875], Loss: 0.8193
# Epoch [1/3], Step [171/1875], Loss: 0.7842
# Epoch [1/3], Step [174/1875], Loss: 0.8091
# Epoch [1/3], Step [177/1875], Loss: 1.1445
# Epoch [1/3], Step [180/1875], Loss: 0.9756
# Epoch [1/3], Step [183/1875], Loss: 0.8325
# Epoch [1/3], Step [186/1875], Loss: 0.7659
# Epoch [1/3], Step [189/1875], Loss: 0.8451
# Epoch [1/3], Step [192/1875], Loss: 0.7433
# Epoch [1/3], Step [195/1875], Loss: 0.6485
# Epoch [1/3], Step [198/1875], Loss: 0.3897
# Epoch [1/3], Step [201/1875], Loss: 0.6317
# Epoch [1/3], Step [204/1875], Loss: 0.4760
# Epoch [1/3], Step [207/1875], Loss: 0.7249
# Epoch [1/3], Step [210/1875], Loss: 0.5354
# Epoch [1/3], Step [213/1875], Loss: 0.7780
# Epoch [1/3], Step [216/1875], Loss: 0.8663
# Epoch [1/3], Step [219/1875], Loss: 0.7772
# Epoch [1/3], Step [222/1875], Loss: 0.4577
# Epoch [1/3], Step [225/1875], Loss: 0.6010
# Epoch [1/3], Step [228/1875], Loss: 0.9359
# Epoch [1/3], Step [231/1875], Loss: 0.6229
# Epoch [1/3], Step [234/1875], Loss: 0.5268
# Epoch [1/3], Step [237/1875], Loss: 0.7747
# Epoch [1/3], Step [240/1875], Loss: 0.8691
# Epoch [1/3], Step [243/1875], Loss: 0.7424
# Epoch [1/3], Step [246/1875], Loss: 0.6863
# Epoch [1/3], Step [249/1875], Loss: 0.6883
# Epoch [1/3], Step [252/1875], Loss: 0.6496
# Epoch [1/3], Step [255/1875], Loss: 0.8768
# Epoch [1/3], Step [258/1875], Loss: 0.5125
# Epoch [1/3], Step [261/1875], Loss: 0.6743
# Epoch [1/3], Step [264/1875], Loss: 0.6884
# Epoch [1/3], Step [267/1875], Loss: 0.6475
# Epoch [1/3], Step [270/1875], Loss: 0.6099
# Epoch [1/3], Step [273/1875], Loss: 0.7510
# Epoch [1/3], Step [276/1875], Loss: 0.7643
# Epoch [1/3], Step [279/1875], Loss: 0.8249
# Epoch [1/3], Step [282/1875], Loss: 0.9469
# Epoch [1/3], Step [285/1875], Loss: 0.7070
# Epoch [1/3], Step [288/1875], Loss: 0.6035
# Epoch [1/3], Step [291/1875], Loss: 0.5090
# Epoch [1/3], Step [294/1875], Loss: 0.8884
# Epoch [1/3], Step [297/1875], Loss: 0.7215
# Epoch [1/3], Step [300/1875], Loss: 0.4416
# Epoch [1/3], Step [303/1875], Loss: 0.9870
# Epoch [1/3], Step [306/1875], Loss: 0.5049
# Epoch [1/3], Step [309/1875], Loss: 0.8753
# Epoch [1/3], Step [312/1875], Loss: 1.0207
# Epoch [1/3], Step [315/1875], Loss: 0.4881
# Epoch [1/3], Step [318/1875], Loss: 0.6903
# Epoch [1/3], Step [321/1875], Loss: 0.7303
# Epoch [1/3], Step [324/1875], Loss: 0.4395
# Epoch [1/3], Step [327/1875], Loss: 0.5251
# Epoch [1/3], Step [330/1875], Loss: 0.8996
# Epoch [1/3], Step [333/1875], Loss: 0.9310
# Epoch [1/3], Step [336/1875], Loss: 0.6259
# Epoch [1/3], Step [339/1875], Loss: 0.5894
# Epoch [1/3], Step [342/1875], Loss: 0.6941
# Epoch [1/3], Step [345/1875], Loss: 0.7506
# Epoch [1/3], Step [348/1875], Loss: 0.5013
# Epoch [1/3], Step [351/1875], Loss: 0.4361
# Epoch [1/3], Step [354/1875], Loss: 0.1942
# Epoch [1/3], Step [357/1875], Loss: 0.5216
# Epoch [1/3], Step [360/1875], Loss: 0.5577
# Epoch [1/3], Step [363/1875], Loss: 0.9179
# Epoch [1/3], Step [366/1875], Loss: 0.5964
# Epoch [1/3], Step [369/1875], Loss: 0.6511
# Epoch [1/3], Step [372/1875], Loss: 0.8604
# Epoch [1/3], Step [375/1875], Loss: 0.7096
# Epoch [1/3], Step [378/1875], Loss: 0.4501
# Epoch [1/3], Step [381/1875], Loss: 0.5380
# Epoch [1/3], Step [384/1875], Loss: 0.3878
# Epoch [1/3], Step [387/1875], Loss: 0.9516
# Epoch [1/3], Step [390/1875], Loss: 0.6654
# Epoch [1/3], Step [393/1875], Loss: 0.4579
# Epoch [1/3], Step [396/1875], Loss: 0.4029
# Epoch [1/3], Step [399/1875], Loss: 0.3171
# Epoch [1/3], Step [402/1875], Loss: 0.4653
# Epoch [1/3], Step [405/1875], Loss: 0.6041
# Epoch [1/3], Step [408/1875], Loss: 0.7470
# Epoch [1/3], Step [411/1875], Loss: 0.6389
# Epoch [1/3], Step [414/1875], Loss: 0.6149
# Epoch [1/3], Step [417/1875], Loss: 0.3868
# Epoch [1/3], Step [420/1875], Loss: 0.7813
# Epoch [1/3], Step [423/1875], Loss: 0.9125
# Epoch [1/3], Step [426/1875], Loss: 0.4629
# Epoch [1/3], Step [429/1875], Loss: 0.5869
# Epoch [1/3], Step [432/1875], Loss: 0.5404
# Epoch [1/3], Step [435/1875], Loss: 0.4045
# Epoch [1/3], Step [438/1875], Loss: 0.7776
# Epoch [1/3], Step [441/1875], Loss: 0.6090
# Epoch [1/3], Step [444/1875], Loss: 0.3957
# Epoch [1/3], Step [447/1875], Loss: 0.7224
# Epoch [1/3], Step [450/1875], Loss: 0.9862
# Epoch [1/3], Step [453/1875], Loss: 0.6804
# Epoch [1/3], Step [456/1875], Loss: 0.8270
# Epoch [1/3], Step [459/1875], Loss: 0.8439
# Epoch [1/3], Step [462/1875], Loss: 0.4281
# Epoch [1/3], Step [465/1875], Loss: 0.4944
# Epoch [1/3], Step [468/1875], Loss: 0.4821
# Epoch [1/3], Step [471/1875], Loss: 0.6148
# Epoch [1/3], Step [474/1875], Loss: 0.5474
# Epoch [1/3], Step [477/1875], Loss: 0.5856
# Epoch [1/3], Step [480/1875], Loss: 0.3277
# Epoch [1/3], Step [483/1875], Loss: 0.6827
# Epoch [1/3], Step [486/1875], Loss: 0.5802
# Epoch [1/3], Step [489/1875], Loss: 0.8478
# Epoch [1/3], Step [492/1875], Loss: 0.8358
# Epoch [1/3], Step [495/1875], Loss: 0.5348
# Epoch [1/3], Step [498/1875], Loss: 0.7242
# Epoch [1/3], Step [501/1875], Loss: 0.6373
# Epoch [1/3], Step [504/1875], Loss: 0.8096
# Epoch [1/3], Step [507/1875], Loss: 0.3736
# Epoch [1/3], Step [510/1875], Loss: 0.7797
# Epoch [1/3], Step [513/1875], Loss: 0.7593
# Epoch [1/3], Step [516/1875], Loss: 0.5560
# Epoch [1/3], Step [519/1875], Loss: 0.6714
# Epoch [1/3], Step [522/1875], Loss: 0.8901
# Epoch [1/3], Step [525/1875], Loss: 1.2709
# Epoch [1/3], Step [528/1875], Loss: 0.7146
# Epoch [1/3], Step [531/1875], Loss: 0.2898
# Epoch [1/3], Step [534/1875], Loss: 0.4474
# Epoch [1/3], Step [537/1875], Loss: 0.5293
# Epoch [1/3], Step [540/1875], Loss: 0.4432
# Epoch [1/3], Step [543/1875], Loss: 0.6431
# Epoch [1/3], Step [546/1875], Loss: 0.8841
# Epoch [1/3], Step [549/1875], Loss: 1.5901
# Epoch [1/3], Step [552/1875], Loss: 0.7070
# Epoch [1/3], Step [555/1875], Loss: 0.7128
# Epoch [1/3], Step [558/1875], Loss: 0.6446
# Epoch [1/3], Step [561/1875], Loss: 0.6429
# Epoch [1/3], Step [564/1875], Loss: 0.5506
# Epoch [1/3], Step [567/1875], Loss: 0.6847
# Epoch [1/3], Step [570/1875], Loss: 0.9933
# Epoch [1/3], Step [573/1875], Loss: 0.5108
# Epoch [1/3], Step [576/1875], Loss: 0.5960
# Epoch [1/3], Step [579/1875], Loss: 0.7245
# Epoch [1/3], Step [582/1875], Loss: 0.7350
# Epoch [1/3], Step [585/1875], Loss: 0.5110
# Epoch [1/3], Step [588/1875], Loss: 0.7311
# Epoch [1/3], Step [591/1875], Loss: 0.6682
# Epoch [1/3], Step [594/1875], Loss: 0.3977
# Epoch [1/3], Step [597/1875], Loss: 0.3436
# Epoch [1/3], Step [600/1875], Loss: 1.1579
# Epoch [1/3], Step [603/1875], Loss: 0.7784
# Epoch [1/3], Step [606/1875], Loss: 0.5323
# Epoch [1/3], Step [609/1875], Loss: 0.9302
# Epoch [1/3], Step [612/1875], Loss: 0.7431
# Epoch [1/3], Step [615/1875], Loss: 0.4955
# Epoch [1/3], Step [618/1875], Loss: 0.6925
# Epoch [1/3], Step [621/1875], Loss: 0.5053
# Epoch [1/3], Step [624/1875], Loss: 0.6444
# Epoch [1/3], Step [627/1875], Loss: 0.8034
# Epoch [1/3], Step [630/1875], Loss: 0.5313
# Epoch [1/3], Step [633/1875], Loss: 0.2968
# Epoch [1/3], Step [636/1875], Loss: 0.7119
# Epoch [1/3], Step [639/1875], Loss: 0.5553
# Epoch [1/3], Step [642/1875], Loss: 0.5715
# Epoch [1/3], Step [645/1875], Loss: 0.5458
# Epoch [1/3], Step [648/1875], Loss: 0.5628
# Epoch [1/3], Step [651/1875], Loss: 0.5972
# Epoch [1/3], Step [654/1875], Loss: 0.7269
# Epoch [1/3], Step [657/1875], Loss: 0.5770
# Epoch [1/3], Step [660/1875], Loss: 0.4638
# Epoch [1/3], Step [663/1875], Loss: 0.6176
# Epoch [1/3], Step [666/1875], Loss: 0.4753
# Epoch [1/3], Step [669/1875], Loss: 0.7740
# Epoch [1/3], Step [672/1875], Loss: 0.7187
# Epoch [1/3], Step [675/1875], Loss: 0.3141
# Epoch [1/3], Step [678/1875], Loss: 0.5625
# Epoch [1/3], Step [681/1875], Loss: 0.6663
# Epoch [1/3], Step [684/1875], Loss: 0.5587
# Epoch [1/3], Step [687/1875], Loss: 0.6159
# Epoch [1/3], Step [690/1875], Loss: 0.6592
# Epoch [1/3], Step [693/1875], Loss: 0.5051
# Epoch [1/3], Step [696/1875], Loss: 0.5962
# Epoch [1/3], Step [699/1875], Loss: 0.6552
# Epoch [1/3], Step [702/1875], Loss: 0.7690
# Epoch [1/3], Step [705/1875], Loss: 0.4210
# Epoch [1/3], Step [708/1875], Loss: 0.3378
# Epoch [1/3], Step [711/1875], Loss: 0.8987
# Epoch [1/3], Step [714/1875], Loss: 0.5436
# Epoch [1/3], Step [717/1875], Loss: 0.9336
# Epoch [1/3], Step [720/1875], Loss: 0.3716
# Epoch [1/3], Step [723/1875], Loss: 0.3434
# Epoch [1/3], Step [726/1875], Loss: 0.5998
# Epoch [1/3], Step [729/1875], Loss: 0.9370
# Epoch [1/3], Step [732/1875], Loss: 0.8340
# Epoch [1/3], Step [735/1875], Loss: 0.7499
# Epoch [1/3], Step [738/1875], Loss: 0.7361
# Epoch [1/3], Step [741/1875], Loss: 0.6344
# Epoch [1/3], Step [744/1875], Loss: 0.7370
# Epoch [1/3], Step [747/1875], Loss: 0.8565
# Epoch [1/3], Step [750/1875], Loss: 0.8188
# Epoch [1/3], Step [753/1875], Loss: 0.7386
# Epoch [1/3], Step [756/1875], Loss: 0.5141
# Epoch [1/3], Step [759/1875], Loss: 0.5481
# Epoch [1/3], Step [762/1875], Loss: 0.6597
# Epoch [1/3], Step [765/1875], Loss: 0.6559
# Epoch [1/3], Step [768/1875], Loss: 0.5791
# Epoch [1/3], Step [771/1875], Loss: 0.5986
# Epoch [1/3], Step [774/1875], Loss: 0.4303
# Epoch [1/3], Step [777/1875], Loss: 0.4231
# Epoch [1/3], Step [780/1875], Loss: 0.4805
# Epoch [1/3], Step [783/1875], Loss: 0.7674
# Epoch [1/3], Step [786/1875], Loss: 0.5728
# Epoch [1/3], Step [789/1875], Loss: 0.3429
# Epoch [1/3], Step [792/1875], Loss: 0.6993
# Epoch [1/3], Step [795/1875], Loss: 0.5843
# Epoch [1/3], Step [798/1875], Loss: 0.2542
# Epoch [1/3], Step [801/1875], Loss: 0.4355
# Epoch [1/3], Step [804/1875], Loss: 0.4116
# Epoch [1/3], Step [807/1875], Loss: 0.6441
# Epoch [1/3], Step [810/1875], Loss: 0.3550
# Epoch [1/3], Step [813/1875], Loss: 0.8426
# Epoch [1/3], Step [816/1875], Loss: 0.9029
# Epoch [1/3], Step [819/1875], Loss: 0.5933
# Epoch [1/3], Step [822/1875], Loss: 0.6999
# Epoch [1/3], Step [825/1875], Loss: 0.7428
# Epoch [1/3], Step [828/1875], Loss: 0.4571
# Epoch [1/3], Step [831/1875], Loss: 0.4232
# Epoch [1/3], Step [834/1875], Loss: 0.5956
# Epoch [1/3], Step [837/1875], Loss: 0.7099
# Epoch [1/3], Step [840/1875], Loss: 0.5346
# Epoch [1/3], Step [843/1875], Loss: 0.8056
# Epoch [1/3], Step [846/1875], Loss: 0.7549
# Epoch [1/3], Step [849/1875], Loss: 1.1208
# Epoch [1/3], Step [852/1875], Loss: 0.7169
# Epoch [1/3], Step [855/1875], Loss: 0.5602
# Epoch [1/3], Step [858/1875], Loss: 0.5289
# Epoch [1/3], Step [861/1875], Loss: 0.6557
# Epoch [1/3], Step [864/1875], Loss: 0.4732
# Epoch [1/3], Step [867/1875], Loss: 0.7232
# Epoch [1/3], Step [870/1875], Loss: 0.6408
# Epoch [1/3], Step [873/1875], Loss: 0.6443
# Epoch [1/3], Step [876/1875], Loss: 0.7580
# Epoch [1/3], Step [879/1875], Loss: 0.3961
# Epoch [1/3], Step [882/1875], Loss: 0.5589
# Epoch [1/3], Step [885/1875], Loss: 0.6884
# Epoch [1/3], Step [888/1875], Loss: 0.5095
# Epoch [1/3], Step [891/1875], Loss: 0.7403
# Epoch [1/3], Step [894/1875], Loss: 0.6696
# Epoch [1/3], Step [897/1875], Loss: 0.5177
# Epoch [1/3], Step [900/1875], Loss: 0.7014
# Epoch [1/3], Step [903/1875], Loss: 0.5237
# Epoch [1/3], Step [906/1875], Loss: 0.8694
# Epoch [1/3], Step [909/1875], Loss: 0.5705
# Epoch [1/3], Step [912/1875], Loss: 0.2877
# Epoch [1/3], Step [915/1875], Loss: 0.4727
# Epoch [1/3], Step [918/1875], Loss: 0.6168
# Epoch [1/3], Step [921/1875], Loss: 0.6521
# Epoch [1/3], Step [924/1875], Loss: 0.5488
# Epoch [1/3], Step [927/1875], Loss: 0.6287
# Epoch [1/3], Step [930/1875], Loss: 0.6295
# Epoch [1/3], Step [933/1875], Loss: 0.3836
# Epoch [1/3], Step [936/1875], Loss: 0.3438
# Epoch [1/3], Step [939/1875], Loss: 0.7879
# Epoch [1/3], Step [942/1875], Loss: 1.1042
# Epoch [1/3], Step [945/1875], Loss: 0.4462
# Epoch [1/3], Step [948/1875], Loss: 0.3836
# Epoch [1/3], Step [951/1875], Loss: 0.3242
# Epoch [1/3], Step [954/1875], Loss: 0.6784
# Epoch [1/3], Step [957/1875], Loss: 0.3771
# Epoch [1/3], Step [960/1875], Loss: 0.5600
# Epoch [1/3], Step [963/1875], Loss: 0.3161
# Epoch [1/3], Step [966/1875], Loss: 0.5435
# Epoch [1/3], Step [969/1875], Loss: 0.5433
# Epoch [1/3], Step [972/1875], Loss: 1.0118
# Epoch [1/3], Step [975/1875], Loss: 0.3843
# Epoch [1/3], Step [978/1875], Loss: 0.4560
# Epoch [1/3], Step [981/1875], Loss: 0.5806
# Epoch [1/3], Step [984/1875], Loss: 0.4292
# Epoch [1/3], Step [987/1875], Loss: 0.4561
# Epoch [1/3], Step [990/1875], Loss: 0.5593
# Epoch [1/3], Step [993/1875], Loss: 0.4544
# Epoch [1/3], Step [996/1875], Loss: 0.5819
# Epoch [1/3], Step [999/1875], Loss: 0.5377
# Epoch [1/3], Step [1002/1875], Loss: 0.3979
# Epoch [1/3], Step [1005/1875], Loss: 0.6792
# Epoch [1/3], Step [1008/1875], Loss: 0.5912
# Epoch [1/3], Step [1011/1875], Loss: 0.4233
# Epoch [1/3], Step [1014/1875], Loss: 0.4913
# Epoch [1/3], Step [1017/1875], Loss: 0.4953
# Epoch [1/3], Step [1020/1875], Loss: 0.3766
# Epoch [1/3], Step [1023/1875], Loss: 0.6885
# Epoch [1/3], Step [1026/1875], Loss: 0.5236
# Epoch [1/3], Step [1029/1875], Loss: 0.3512
# Epoch [1/3], Step [1032/1875], Loss: 0.6105
# Epoch [1/3], Step [1035/1875], Loss: 0.4386
# Epoch [1/3], Step [1038/1875], Loss: 0.2671
# Epoch [1/3], Step [1041/1875], Loss: 0.5192
# Epoch [1/3], Step [1044/1875], Loss: 0.5442
# Epoch [1/3], Step [1047/1875], Loss: 0.3489
# Epoch [1/3], Step [1050/1875], Loss: 0.6074
# Epoch [1/3], Step [1053/1875], Loss: 0.7200
# Epoch [1/3], Step [1056/1875], Loss: 0.4879
# Epoch [1/3], Step [1059/1875], Loss: 0.4845
# Epoch [1/3], Step [1062/1875], Loss: 0.6015
# Epoch [1/3], Step [1065/1875], Loss: 0.2724
# Epoch [1/3], Step [1068/1875], Loss: 0.5804
# Epoch [1/3], Step [1071/1875], Loss: 0.6537
# Epoch [1/3], Step [1074/1875], Loss: 0.5586
# Epoch [1/3], Step [1077/1875], Loss: 0.9928
# Epoch [1/3], Step [1080/1875], Loss: 0.6925
# Epoch [1/3], Step [1083/1875], Loss: 0.4263
# Epoch [1/3], Step [1086/1875], Loss: 0.4360
# Epoch [1/3], Step [1089/1875], Loss: 0.6256
# Epoch [1/3], Step [1092/1875], Loss: 0.6250
# Epoch [1/3], Step [1095/1875], Loss: 0.8507
# Epoch [1/3], Step [1098/1875], Loss: 0.5065
# Epoch [1/3], Step [1101/1875], Loss: 0.3430
# Epoch [1/3], Step [1104/1875], Loss: 0.4462
# Epoch [1/3], Step [1107/1875], Loss: 0.6253
# Epoch [1/3], Step [1110/1875], Loss: 0.7108
# Epoch [1/3], Step [1113/1875], Loss: 0.8088
# Epoch [1/3], Step [1116/1875], Loss: 0.4441
# Epoch [1/3], Step [1119/1875], Loss: 0.6477
# Epoch [1/3], Step [1122/1875], Loss: 0.5953
# Epoch [1/3], Step [1125/1875], Loss: 0.6802
# Epoch [1/3], Step [1128/1875], Loss: 0.6045
# Epoch [1/3], Step [1131/1875], Loss: 0.3741
# Epoch [1/3], Step [1134/1875], Loss: 0.4563
# Epoch [1/3], Step [1458/1875], Loss: 0.5625
# Epoch [1/3], Step [1461/1875], Loss: 0.2673
# Epoch [1/3], Step [1464/1875], Loss: 0.3073
# Epoch [1/3], Step [1467/1875], Loss: 0.4144
# Epoch [1/3], Step [1470/1875], Loss: 0.4181
# Epoch [1/3], Step [1473/1875], Loss: 0.3419
# Epoch [1/3], Step [1476/1875], Loss: 0.4460
# Epoch [1/3], Step [1479/1875], Loss: 0.3546
# Epoch [1/3], Step [1482/1875], Loss: 0.6317
# Epoch [1/3], Step [1485/1875], Loss: 0.7185
# Epoch [1/3], Step [1488/1875], Loss: 0.4339
# Epoch [1/3], Step [1491/1875], Loss: 0.4316
# Epoch [1/3], Step [1494/1875], Loss: 0.4903
# Epoch [1/3], Step [1497/1875], Loss: 0.5103
# Epoch [1/3], Step [1500/1875], Loss: 0.5902
# Epoch [1/3], Step [1503/1875], Loss: 0.6266
# Epoch [1/3], Step [1506/1875], Loss: 0.4348
# Epoch [1/3], Step [1509/1875], Loss: 0.2478
# Epoch [1/3], Step [1512/1875], Loss: 0.3956
# Epoch [1/3], Step [1515/1875], Loss: 0.7034
# Epoch [1/3], Step [1518/1875], Loss: 0.5197
# Epoch [1/3], Step [1521/1875], Loss: 0.3003
# Epoch [1/3], Step [1524/1875], Loss: 0.6534
# Epoch [1/3], Step [1527/1875], Loss: 0.6714
# Epoch [1/3], Step [1530/1875], Loss: 1.1119
# Epoch [1/3], Step [1533/1875], Loss: 0.4416
# Epoch [1/3], Step [1536/1875], Loss: 0.6631
# Epoch [1/3], Step [1539/1875], Loss: 0.5771
# Epoch [1/3], Step [1542/1875], Loss: 0.2971
# Epoch [1/3], Step [1545/1875], Loss: 0.3736
# Epoch [1/3], Step [1548/1875], Loss: 0.5025
# Epoch [1/3], Step [1551/1875], Loss: 0.5174
# Epoch [1/3], Step [1554/1875], Loss: 0.6119
# Epoch [1/3], Step [1557/1875], Loss: 0.6496
# Epoch [1/3], Step [1560/1875], Loss: 0.3502
# Epoch [1/3], Step [1563/1875], Loss: 0.5020
# Epoch [1/3], Step [1566/1875], Loss: 0.2991
# Epoch [1/3], Step [1569/1875], Loss: 0.4935
# Epoch [1/3], Step [1572/1875], Loss: 0.3196
# Epoch [1/3], Step [1575/1875], Loss: 0.3933
# Epoch [1/3], Step [1578/1875], Loss: 0.5686
# Epoch [1/3], Step [1581/1875], Loss: 0.5949
# Epoch [1/3], Step [1584/1875], Loss: 0.3440
# Epoch [1/3], Step [1587/1875], Loss: 0.3176
# Epoch [1/3], Step [1590/1875], Loss: 0.3652
# Epoch [1/3], Step [1593/1875], Loss: 0.4626
# Epoch [1/3], Step [1596/1875], Loss: 0.3054
# Epoch [1/3], Step [1599/1875], Loss: 0.4843
# Epoch [1/3], Step [1602/1875], Loss: 0.9257
# Epoch [1/3], Step [1605/1875], Loss: 0.6688
# Epoch [1/3], Step [1608/1875], Loss: 0.2535
# Epoch [1/3], Step [1611/1875], Loss: 0.3919
# Epoch [1/3], Step [1614/1875], Loss: 0.4323
# Epoch [1/3], Step [1617/1875], Loss: 0.6344
# Epoch [1/3], Step [1620/1875], Loss: 0.7291
# Epoch [1/3], Step [1623/1875], Loss: 0.4676
# Epoch [1/3], Step [1626/1875], Loss: 0.5251
# Epoch [1/3], Step [1629/1875], Loss: 0.4842
# Epoch [1/3], Step [1632/1875], Loss: 0.3275
# Epoch [1/3], Step [1635/1875], Loss: 0.8498
# Epoch [1/3], Step [1638/1875], Loss: 0.3637
# Epoch [1/3], Step [1641/1875], Loss: 0.4767
# Epoch [1/3], Step [1644/1875], Loss: 0.7536
# Epoch [1/3], Step [1647/1875], Loss: 0.3506
# Epoch [1/3], Step [1650/1875], Loss: 0.4430
# Epoch [1/3], Step [1653/1875], Loss: 0.5661
# Epoch [1/3], Step [1656/1875], Loss: 0.4938
# Epoch [1/3], Step [1659/1875], Loss: 0.4254
# Epoch [1/3], Step [1662/1875], Loss: 0.6724
# Epoch [1/3], Step [1665/1875], Loss: 0.7384
# Epoch [1/3], Step [1668/1875], Loss: 0.6045
# Epoch [1/3], Step [1671/1875], Loss: 0.3951
# Epoch [1/3], Step [1674/1875], Loss: 0.2325
# Epoch [1/3], Step [1677/1875], Loss: 0.4907
# Epoch [1/3], Step [1680/1875], Loss: 0.4665
# Epoch [1/3], Step [1683/1875], Loss: 0.5882
# Epoch [1/3], Step [1686/1875], Loss: 0.6015
# Epoch [1/3], Step [1689/1875], Loss: 0.7914
# Epoch [1/3], Step [1692/1875], Loss: 0.5734
# Epoch [1/3], Step [1695/1875], Loss: 0.5875
# Epoch [1/3], Step [1698/1875], Loss: 0.7313
# Epoch [1/3], Step [1701/1875], Loss: 0.3007
# Epoch [1/3], Step [1704/1875], Loss: 0.7470
# Epoch [1/3], Step [1707/1875], Loss: 0.4884
# Epoch [1/3], Step [1710/1875], Loss: 0.5367
# Epoch [1/3], Step [1713/1875], Loss: 0.6877
# Epoch [1/3], Step [1716/1875], Loss: 0.5962
# Epoch [1/3], Step [1719/1875], Loss: 0.6307
# Epoch [1/3], Step [1722/1875], Loss: 0.8689
# Epoch [1/3], Step [1725/1875], Loss: 0.4411
# Epoch [1/3], Step [1728/1875], Loss: 0.5984
# Epoch [1/3], Step [1731/1875], Loss: 0.6958
# Epoch [1/3], Step [1734/1875], Loss: 0.3006
# Epoch [1/3], Step [1737/1875], Loss: 0.4618
# Epoch [1/3], Step [1740/1875], Loss: 0.3647
# Epoch [1/3], Step [1743/1875], Loss: 0.6447
# Epoch [1/3], Step [1746/1875], Loss: 0.3578
# Epoch [1/3], Step [1749/1875], Loss: 0.8549
# Epoch [1/3], Step [1752/1875], Loss: 0.5710
# Epoch [1/3], Step [1755/1875], Loss: 0.5365
# Epoch [1/3], Step [1758/1875], Loss: 0.4234
# Epoch [1/3], Step [1761/1875], Loss: 0.3847
# Epoch [1/3], Step [1764/1875], Loss: 0.5618
# Epoch [1/3], Step [1767/1875], Loss: 0.4251
# Epoch [1/3], Step [1770/1875], Loss: 0.5109
# Epoch [1/3], Step [1773/1875], Loss: 0.4269
# Epoch [1/3], Step [1776/1875], Loss: 0.4515
# Epoch [1/3], Step [1779/1875], Loss: 0.5696
# Epoch [1/3], Step [1782/1875], Loss: 0.4454
# Epoch [1/3], Step [1785/1875], Loss: 0.5183
# Epoch [1/3], Step [1788/1875], Loss: 0.6270
# Epoch [1/3], Step [1791/1875], Loss: 0.5427
# Epoch [1/3], Step [1794/1875], Loss: 0.7405
# Epoch [1/3], Step [1797/1875], Loss: 0.2287
# Epoch [1/3], Step [1800/1875], Loss: 0.4946
# Epoch [1/3], Step [1803/1875], Loss: 0.2676
# Epoch [1/3], Step [1806/1875], Loss: 0.7559
# Epoch [1/3], Step [1809/1875], Loss: 0.6324
# Epoch [1/3], Step [1812/1875], Loss: 0.4858
# Epoch [1/3], Step [1815/1875], Loss: 0.3933
# Epoch [1/3], Step [1818/1875], Loss: 0.3524
# Epoch [1/3], Step [1821/1875], Loss: 0.3279
# Epoch [1/3], Step [1824/1875], Loss: 0.5310
# Epoch [1/3], Step [1827/1875], Loss: 0.7243
# Epoch [1/3], Step [1830/1875], Loss: 0.4559
# Epoch [1/3], Step [1833/1875], Loss: 0.5362
# Epoch [1/3], Step [1836/1875], Loss: 0.4709
# Epoch [1/3], Step [1839/1875], Loss: 0.6500
# Epoch [1/3], Step [1842/1875], Loss: 0.7489
# Epoch [1/3], Step [1845/1875], Loss: 0.4808
# Epoch [1/3], Step [1848/1875], Loss: 0.3663
# Epoch [1/3], Step [1851/1875], Loss: 0.6048
# Epoch [1/3], Step [1854/1875], Loss: 0.3307
# Epoch [1/3], Step [1857/1875], Loss: 0.7004
# Epoch [1/3], Step [1860/1875], Loss: 0.9786
# Epoch [1/3], Step [1863/1875], Loss: 0.3313
# Epoch [1/3], Step [1866/1875], Loss: 0.5575
# Epoch [1/3], Step [1869/1875], Loss: 0.2042
# Epoch [1/3], Step [1872/1875], Loss: 0.3553
# Epoch [1/3], Step [1875/1875], Loss: 0.4056
# Epoch [2/3], Step [3/1875], Loss: 0.6339
# Epoch [2/3], Step [6/1875], Loss: 0.8645
# Epoch [2/3], Step [9/1875], Loss: 0.6908
# Epoch [2/3], Step [12/1875], Loss: 0.3039
# Epoch [2/3], Step [15/1875], Loss: 0.6124
# Epoch [2/3], Step [18/1875], Loss: 0.4703
# Epoch [2/3], Step [21/1875], Loss: 0.6402
# Epoch [2/3], Step [24/1875], Loss: 0.4177
# Epoch [2/3], Step [27/1875], Loss: 0.6549
# Epoch [2/3], Step [30/1875], Loss: 0.3972
# Epoch [2/3], Step [33/1875], Loss: 0.3859
# Epoch [2/3], Step [36/1875], Loss: 0.5024
# Epoch [2/3], Step [39/1875], Loss: 0.9704
# Epoch [2/3], Step [42/1875], Loss: 0.7818
# Epoch [2/3], Step [45/1875], Loss: 0.3171
# Epoch [2/3], Step [48/1875], Loss: 0.3631
# Epoch [2/3], Step [51/1875], Loss: 0.3393
# Epoch [2/3], Step [54/1875], Loss: 0.4774
# Epoch [2/3], Step [57/1875], Loss: 0.6481
# Epoch [2/3], Step [60/1875], Loss: 0.2568
# Epoch [2/3], Step [63/1875], Loss: 0.4519
# Epoch [2/3], Step [66/1875], Loss: 0.7809
# Epoch [2/3], Step [69/1875], Loss: 0.4700
# Epoch [2/3], Step [72/1875], Loss: 0.6096
# Epoch [2/3], Step [75/1875], Loss: 0.5321
# Epoch [2/3], Step [78/1875], Loss: 0.2982
# Epoch [2/3], Step [81/1875], Loss: 0.4444
# Epoch [2/3], Step [84/1875], Loss: 0.3072
# Epoch [2/3], Step [87/1875], Loss: 0.4734
# Epoch [2/3], Step [90/1875], Loss: 0.8081
# Epoch [2/3], Step [93/1875], Loss: 0.4796
# Epoch [2/3], Step [96/1875], Loss: 0.3368
# Epoch [2/3], Step [99/1875], Loss: 0.4263
# Epoch [2/3], Step [102/1875], Loss: 0.5543
# Epoch [2/3], Step [105/1875], Loss: 0.4742
# Epoch [2/3], Step [108/1875], Loss: 0.6060
# Epoch [2/3], Step [111/1875], Loss: 0.4955
# Epoch [2/3], Step [114/1875], Loss: 0.7501
# Epoch [2/3], Step [117/1875], Loss: 0.5990
# Epoch [2/3], Step [120/1875], Loss: 0.6633
# Epoch [2/3], Step [123/1875], Loss: 0.3433
# Epoch [2/3], Step [126/1875], Loss: 0.6515
# Epoch [2/3], Step [129/1875], Loss: 0.3280
# Epoch [2/3], Step [132/1875], Loss: 0.2557
# Epoch [2/3], Step [135/1875], Loss: 0.4806
# Epoch [2/3], Step [138/1875], Loss: 0.5650
# Epoch [2/3], Step [141/1875], Loss: 0.4313
# Epoch [2/3], Step [144/1875], Loss: 0.4158
# Epoch [2/3], Step [147/1875], Loss: 0.3201
# Epoch [2/3], Step [150/1875], Loss: 0.3809
# Epoch [2/3], Step [153/1875], Loss: 0.4149
# Epoch [2/3], Step [156/1875], Loss: 0.2320
# Epoch [2/3], Step [159/1875], Loss: 0.6772
# Epoch [2/3], Step [162/1875], Loss: 0.3035
# Epoch [2/3], Step [165/1875], Loss: 0.2963
# Epoch [2/3], Step [168/1875], Loss: 0.5643
# Epoch [2/3], Step [171/1875], Loss: 0.4271
# Epoch [2/3], Step [174/1875], Loss: 0.4353
# Epoch [2/3], Step [177/1875], Loss: 0.4391
# Epoch [2/3], Step [180/1875], Loss: 0.5681
# Epoch [2/3], Step [183/1875], Loss: 0.6314
# Epoch [2/3], Step [186/1875], Loss: 0.3473
# Epoch [2/3], Step [189/1875], Loss: 0.2538
# Epoch [2/3], Step [192/1875], Loss: 0.6944
# Epoch [2/3], Step [195/1875], Loss: 0.6233
# Epoch [2/3], Step [198/1875], Loss: 0.4108
# Epoch [2/3], Step [201/1875], Loss: 0.6769
# Epoch [2/3], Step [204/1875], Loss: 0.5628
# Epoch [2/3], Step [207/1875], Loss: 0.5170
# Epoch [2/3], Step [210/1875], Loss: 0.6723
# Epoch [2/3], Step [213/1875], Loss: 0.4478
# Epoch [2/3], Step [216/1875], Loss: 0.8171
# Epoch [2/3], Step [219/1875], Loss: 0.7588
# Epoch [2/3], Step [222/1875], Loss: 0.4245
# Epoch [2/3], Step [225/1875], Loss: 0.6831
# Epoch [2/3], Step [228/1875], Loss: 0.7715
# Epoch [2/3], Step [231/1875], Loss: 0.4654
# Epoch [2/3], Step [234/1875], Loss: 0.5124
# Epoch [2/3], Step [237/1875], Loss: 0.2566
# Epoch [2/3], Step [240/1875], Loss: 0.3301
# Epoch [2/3], Step [243/1875], Loss: 0.6476
# Epoch [2/3], Step [246/1875], Loss: 0.3311
# Epoch [2/3], Step [249/1875], Loss: 0.7837
# Epoch [2/3], Step [252/1875], Loss: 0.3134
# Epoch [2/3], Step [255/1875], Loss: 0.3878
# Epoch [2/3], Step [258/1875], Loss: 0.1826
# Epoch [2/3], Step [261/1875], Loss: 0.3406
# Epoch [2/3], Step [264/1875], Loss: 0.2651
# Epoch [2/3], Step [267/1875], Loss: 0.4533
# Epoch [2/3], Step [270/1875], Loss: 0.7408
# Epoch [2/3], Step [273/1875], Loss: 0.3523
# Epoch [2/3], Step [276/1875], Loss: 0.4118
# Epoch [2/3], Step [279/1875], Loss: 0.3714
# Epoch [2/3], Step [282/1875], Loss: 0.5332
# Epoch [2/3], Step [285/1875], Loss: 0.6434
# Epoch [2/3], Step [288/1875], Loss: 0.4596
# Epoch [2/3], Step [291/1875], Loss: 0.7501
# Epoch [2/3], Step [294/1875], Loss: 0.4624
# Epoch [2/3], Step [297/1875], Loss: 0.3373
# Epoch [2/3], Step [300/1875], Loss: 0.3788
# Epoch [2/3], Step [303/1875], Loss: 0.6277
# Epoch [2/3], Step [306/1875], Loss: 0.3505
# Epoch [2/3], Step [309/1875], Loss: 0.7591
# Epoch [2/3], Step [312/1875], Loss: 0.7163
# Epoch [2/3], Step [315/1875], Loss: 0.6298
# Epoch [2/3], Step [318/1875], Loss: 0.3331
# Epoch [2/3], Step [321/1875], Loss: 0.6896
# Epoch [2/3], Step [324/1875], Loss: 0.2974
# Epoch [2/3], Step [327/1875], Loss: 0.5984
# Epoch [2/3], Step [330/1875], Loss: 0.4163
# Epoch [2/3], Step [333/1875], Loss: 0.6295
# Epoch [2/3], Step [336/1875], Loss: 0.2213
# Epoch [2/3], Step [339/1875], Loss: 0.7865
# Epoch [2/3], Step [342/1875], Loss: 0.5973
# Epoch [2/3], Step [345/1875], Loss: 0.7224
# Epoch [2/3], Step [348/1875], Loss: 0.5641
# Epoch [2/3], Step [351/1875], Loss: 0.6688
# Epoch [2/3], Step [354/1875], Loss: 0.4623
# Epoch [2/3], Step [357/1875], Loss: 0.5609
# Epoch [2/3], Step [360/1875], Loss: 0.5488
# Epoch [2/3], Step [363/1875], Loss: 0.5165
# Epoch [2/3], Step [366/1875], Loss: 0.4816
# Epoch [2/3], Step [369/1875], Loss: 0.6605
# Epoch [2/3], Step [372/1875], Loss: 0.2364
# Epoch [2/3], Step [375/1875], Loss: 0.2982
# Epoch [2/3], Step [378/1875], Loss: 0.4658
# Epoch [2/3], Step [381/1875], Loss: 0.4053
# Epoch [2/3], Step [384/1875], Loss: 0.5041
# Epoch [2/3], Step [387/1875], Loss: 0.7054
# Epoch [2/3], Step [390/1875], Loss: 0.4293
# Epoch [2/3], Step [393/1875], Loss: 0.5162
# Epoch [2/3], Step [396/1875], Loss: 0.6885
# Epoch [2/3], Step [399/1875], Loss: 0.3365
# Epoch [2/3], Step [402/1875], Loss: 0.4235
# Epoch [2/3], Step [405/1875], Loss: 0.8457
# Epoch [2/3], Step [408/1875], Loss: 0.3550
# Epoch [2/3], Step [411/1875], Loss: 0.3061
# Epoch [2/3], Step [414/1875], Loss: 0.3849
# Epoch [2/3], Step [417/1875], Loss: 0.2756
# Epoch [2/3], Step [420/1875], Loss: 0.4729
# Epoch [2/3], Step [423/1875], Loss: 0.4724
# Epoch [2/3], Step [426/1875], Loss: 0.4489
# Epoch [2/3], Step [429/1875], Loss: 0.9610
# Epoch [2/3], Step [432/1875], Loss: 0.4150
# Epoch [2/3], Step [435/1875], Loss: 0.2385
# Epoch [2/3], Step [438/1875], Loss: 0.3962
# Epoch [2/3], Step [441/1875], Loss: 0.4423
# Epoch [2/3], Step [444/1875], Loss: 0.6156
# Epoch [2/3], Step [447/1875], Loss: 0.3056
# Epoch [2/3], Step [450/1875], Loss: 0.2689
# Epoch [2/3], Step [453/1875], Loss: 0.6211
# Epoch [2/3], Step [456/1875], Loss: 0.6204
# Epoch [2/3], Step [459/1875], Loss: 0.3254
# Epoch [2/3], Step [462/1875], Loss: 0.4198
# Epoch [2/3], Step [465/1875], Loss: 0.3653
# Epoch [2/3], Step [468/1875], Loss: 0.7821
# Epoch [2/3], Step [471/1875], Loss: 0.4709
# Epoch [2/3], Step [474/1875], Loss: 0.3387
# Epoch [2/3], Step [477/1875], Loss: 0.7742
# Epoch [2/3], Step [480/1875], Loss: 0.3648
# Epoch [2/3], Step [483/1875], Loss: 0.5676
# Epoch [2/3], Step [486/1875], Loss: 0.3896
# Epoch [2/3], Step [489/1875], Loss: 0.4995
# Epoch [2/3], Step [492/1875], Loss: 0.3888
# Epoch [2/3], Step [495/1875], Loss: 0.4397
# Epoch [2/3], Step [498/1875], Loss: 0.4664
# Epoch [2/3], Step [501/1875], Loss: 0.2152
# Epoch [2/3], Step [504/1875], Loss: 0.3837
# Epoch [2/3], Step [507/1875], Loss: 0.5330
# Epoch [2/3], Step [510/1875], Loss: 0.2829
# Epoch [2/3], Step [513/1875], Loss: 0.3195
# Epoch [2/3], Step [516/1875], Loss: 0.4620
# Epoch [2/3], Step [519/1875], Loss: 0.3356
# Epoch [2/3], Step [522/1875], Loss: 0.2855
# Epoch [2/3], Step [525/1875], Loss: 0.6027
# Epoch [2/3], Step [528/1875], Loss: 0.6818
# Epoch [2/3], Step [531/1875], Loss: 0.6728
# Epoch [2/3], Step [534/1875], Loss: 0.5339
# Epoch [2/3], Step [537/1875], Loss: 0.7013
# Epoch [2/3], Step [540/1875], Loss: 0.3709
# Epoch [2/3], Step [543/1875], Loss: 0.7897
# Epoch [2/3], Step [546/1875], Loss: 0.8853
# Epoch [2/3], Step [549/1875], Loss: 0.4556
# Epoch [2/3], Step [552/1875], Loss: 0.5041
# Epoch [2/3], Step [555/1875], Loss: 0.5175
# Epoch [2/3], Step [558/1875], Loss: 0.3003
# Epoch [2/3], Step [561/1875], Loss: 0.3325
# Epoch [2/3], Step [564/1875], Loss: 0.3133
# Epoch [2/3], Step [567/1875], Loss: 0.4140
# Epoch [2/3], Step [570/1875], Loss: 0.3661
# Epoch [2/3], Step [573/1875], Loss: 0.4855
# Epoch [2/3], Step [576/1875], Loss: 0.7037
# Epoch [2/3], Step [579/1875], Loss: 0.4427
# Epoch [2/3], Step [582/1875], Loss: 0.9341
# Epoch [2/3], Step [585/1875], Loss: 0.3481
# Epoch [2/3], Step [588/1875], Loss: 0.2843
# Epoch [2/3], Step [591/1875], Loss: 0.3172
# Epoch [2/3], Step [594/1875], Loss: 0.5173
# Epoch [2/3], Step [597/1875], Loss: 0.2723
# Epoch [2/3], Step [600/1875], Loss: 0.3467
# Epoch [2/3], Step [603/1875], Loss: 0.6285
# Epoch [2/3], Step [606/1875], Loss: 0.7727
# Epoch [2/3], Step [609/1875], Loss: 0.8720
# Epoch [2/3], Step [612/1875], Loss: 0.3470
# Epoch [2/3], Step [615/1875], Loss: 0.6643
# Epoch [2/3], Step [618/1875], Loss: 0.5335
# Epoch [2/3], Step [621/1875], Loss: 0.5617
# Epoch [2/3], Step [624/1875], Loss: 0.1556
# Epoch [2/3], Step [627/1875], Loss: 0.2425
# Epoch [2/3], Step [630/1875], Loss: 0.5083
# Epoch [2/3], Step [633/1875], Loss: 0.8020
# Epoch [2/3], Step [636/1875], Loss: 0.5955
# Epoch [2/3], Step [639/1875], Loss: 0.3256
# Epoch [2/3], Step [642/1875], Loss: 0.6325
# Epoch [2/3], Step [645/1875], Loss: 0.4644
# Epoch [2/3], Step [648/1875], Loss: 0.6804
# Epoch [2/3], Step [651/1875], Loss: 0.7028
# Epoch [2/3], Step [654/1875], Loss: 0.4781
# Epoch [2/3], Step [657/1875], Loss: 0.3779
# Epoch [2/3], Step [660/1875], Loss: 0.6312
# Epoch [2/3], Step [663/1875], Loss: 0.5546
# Epoch [2/3], Step [666/1875], Loss: 0.5759
# Epoch [2/3], Step [669/1875], Loss: 0.5424
# Epoch [2/3], Step [672/1875], Loss: 0.2915
# Epoch [2/3], Step [675/1875], Loss: 0.5212
# Epoch [2/3], Step [678/1875], Loss: 0.7127
# Epoch [2/3], Step [681/1875], Loss: 0.2957
# Epoch [2/3], Step [684/1875], Loss: 0.4666
# Epoch [2/3], Step [687/1875], Loss: 0.6957
# Epoch [2/3], Step [690/1875], Loss: 0.3382
# Epoch [2/3], Step [693/1875], Loss: 0.3408
# Epoch [2/3], Step [696/1875], Loss: 0.6251
# Epoch [2/3], Step [699/1875], Loss: 0.5149
# Epoch [2/3], Step [702/1875], Loss: 0.4330
# Epoch [2/3], Step [705/1875], Loss: 0.6910
# Epoch [2/3], Step [708/1875], Loss: 0.4065
# Epoch [2/3], Step [711/1875], Loss: 0.4998
# Epoch [2/3], Step [714/1875], Loss: 0.8515
# Epoch [2/3], Step [717/1875], Loss: 0.2870
# Epoch [2/3], Step [720/1875], Loss: 0.4662
# Epoch [2/3], Step [723/1875], Loss: 0.3970
# Epoch [2/3], Step [726/1875], Loss: 0.2306
# Epoch [2/3], Step [729/1875], Loss: 0.5455
# Epoch [2/3], Step [732/1875], Loss: 0.3537
# Epoch [2/3], Step [735/1875], Loss: 0.2452
# Epoch [2/3], Step [738/1875], Loss: 0.8774
# Epoch [2/3], Step [741/1875], Loss: 0.6443
# Epoch [2/3], Step [744/1875], Loss: 0.6966
# Epoch [2/3], Step [747/1875], Loss: 0.5026
# Epoch [2/3], Step [750/1875], Loss: 0.8326
# Epoch [2/3], Step [753/1875], Loss: 0.2431
# Epoch [2/3], Step [756/1875], Loss: 0.4949
# Epoch [2/3], Step [759/1875], Loss: 0.4884
# Epoch [2/3], Step [762/1875], Loss: 0.2084
# Epoch [2/3], Step [765/1875], Loss: 0.4900
# Epoch [2/3], Step [768/1875], Loss: 0.2697
# Epoch [2/3], Step [771/1875], Loss: 0.4070
# Epoch [2/3], Step [774/1875], Loss: 0.6627
# Epoch [2/3], Step [777/1875], Loss: 0.6092
# Epoch [2/3], Step [780/1875], Loss: 0.6107
# Epoch [2/3], Step [783/1875], Loss: 0.4601
# Epoch [2/3], Step [786/1875], Loss: 0.4825
# Epoch [2/3], Step [789/1875], Loss: 0.4096
# Epoch [2/3], Step [792/1875], Loss: 0.7834
# Epoch [2/3], Step [795/1875], Loss: 0.6699
# Epoch [2/3], Step [798/1875], Loss: 0.4080
# Epoch [2/3], Step [801/1875], Loss: 0.4037
# Epoch [2/3], Step [804/1875], Loss: 0.5742
# Epoch [2/3], Step [807/1875], Loss: 0.3853
# Epoch [2/3], Step [810/1875], Loss: 0.3961
# Epoch [2/3], Step [813/1875], Loss: 0.5453
# Epoch [2/3], Step [816/1875], Loss: 0.2724
# Epoch [2/3], Step [819/1875], Loss: 0.3095
# Epoch [2/3], Step [822/1875], Loss: 0.5223
# Epoch [2/3], Step [825/1875], Loss: 0.6926
# Epoch [2/3], Step [828/1875], Loss: 0.5005
# Epoch [2/3], Step [831/1875], Loss: 0.9979
# Epoch [2/3], Step [834/1875], Loss: 0.2720
# Epoch [2/3], Step [837/1875], Loss: 0.3934
# Epoch [2/3], Step [840/1875], Loss: 0.4037
# Epoch [2/3], Step [843/1875], Loss: 0.3194
# Epoch [2/3], Step [846/1875], Loss: 0.3251
# Epoch [2/3], Step [849/1875], Loss: 0.2863
# Epoch [2/3], Step [852/1875], Loss: 0.2392
# Epoch [2/3], Step [855/1875], Loss: 0.3810
# Epoch [2/3], Step [858/1875], Loss: 0.2735
# Epoch [2/3], Step [861/1875], Loss: 0.5298
# Epoch [2/3], Step [864/1875], Loss: 0.5916
# Epoch [2/3], Step [867/1875], Loss: 0.3310
# Epoch [2/3], Step [870/1875], Loss: 0.6517
# Epoch [2/3], Step [873/1875], Loss: 0.3981
# Epoch [2/3], Step [876/1875], Loss: 0.4887
# Epoch [2/3], Step [879/1875], Loss: 0.6492
# Epoch [2/3], Step [882/1875], Loss: 0.4170
# Epoch [2/3], Step [885/1875], Loss: 0.5704
# Epoch [2/3], Step [888/1875], Loss: 0.3442
# Epoch [2/3], Step [891/1875], Loss: 0.4676
# Epoch [2/3], Step [894/1875], Loss: 0.4751
# Epoch [2/3], Step [897/1875], Loss: 0.3796
# Epoch [2/3], Step [900/1875], Loss: 0.4283
# Epoch [2/3], Step [903/1875], Loss: 0.3389
# Epoch [2/3], Step [906/1875], Loss: 0.1952
# Epoch [2/3], Step [909/1875], Loss: 0.4099
# Epoch [2/3], Step [912/1875], Loss: 0.4491
# Epoch [2/3], Step [915/1875], Loss: 0.6812
# Epoch [2/3], Step [918/1875], Loss: 0.6522
# Epoch [2/3], Step [921/1875], Loss: 0.8446
# Epoch [2/3], Step [924/1875], Loss: 0.4194
# Epoch [2/3], Step [927/1875], Loss: 0.7362
# Epoch [2/3], Step [930/1875], Loss: 0.2913
# Epoch [2/3], Step [933/1875], Loss: 0.3603
# Epoch [2/3], Step [936/1875], Loss: 0.3888
# Epoch [2/3], Step [939/1875], Loss: 0.6499
# Epoch [2/3], Step [942/1875], Loss: 0.3687
# Epoch [2/3], Step [945/1875], Loss: 0.4044
# Epoch [2/3], Step [948/1875], Loss: 0.2921
# Epoch [2/3], Step [951/1875], Loss: 0.4535
# Epoch [2/3], Step [954/1875], Loss: 0.4270
# Epoch [2/3], Step [957/1875], Loss: 0.3976
# Epoch [2/3], Step [960/1875], Loss: 0.4566
# Epoch [2/3], Step [963/1875], Loss: 0.5488
# Epoch [2/3], Step [966/1875], Loss: 0.5140
# Epoch [2/3], Step [969/1875], Loss: 0.2189
# Epoch [2/3], Step [972/1875], Loss: 0.3340
# Epoch [2/3], Step [975/1875], Loss: 0.7986
# Epoch [2/3], Step [978/1875], Loss: 0.5757
# Epoch [2/3], Step [981/1875], Loss: 0.4491
# Epoch [2/3], Step [984/1875], Loss: 0.6228
# Epoch [2/3], Step [987/1875], Loss: 0.5831
# Epoch [2/3], Step [990/1875], Loss: 0.4937
# Epoch [2/3], Step [993/1875], Loss: 0.7336
# Epoch [2/3], Step [996/1875], Loss: 0.4874
# Epoch [2/3], Step [999/1875], Loss: 0.5944
# Epoch [2/3], Step [1002/1875], Loss: 0.2378
# Epoch [2/3], Step [1005/1875], Loss: 0.6110
# Epoch [2/3], Step [1008/1875], Loss: 0.6878
# Epoch [2/3], Step [1011/1875], Loss: 0.7715
# Epoch [2/3], Step [1014/1875], Loss: 0.4158
# Epoch [2/3], Step [1017/1875], Loss: 0.3290
# Epoch [2/3], Step [1020/1875], Loss: 0.5077
# Epoch [2/3], Step [1023/1875], Loss: 0.6142
# Epoch [2/3], Step [1026/1875], Loss: 0.6580
# Epoch [2/3], Step [1029/1875], Loss: 0.5603
# Epoch [2/3], Step [1032/1875], Loss: 0.3674
# Epoch [2/3], Step [1035/1875], Loss: 0.4349
# Epoch [2/3], Step [1038/1875], Loss: 0.5245
# Epoch [2/3], Step [1041/1875], Loss: 0.4324
# Epoch [2/3], Step [1044/1875], Loss: 0.2271
# Epoch [2/3], Step [1047/1875], Loss: 0.9076
# Epoch [2/3], Step [1050/1875], Loss: 0.6190
# Epoch [2/3], Step [1053/1875], Loss: 0.4547
# Epoch [2/3], Step [1056/1875], Loss: 0.4148
# Epoch [2/3], Step [1059/1875], Loss: 0.6269
# Epoch [2/3], Step [1062/1875], Loss: 0.2884
# Epoch [2/3], Step [1386/1875], Loss: 0.4259
# Epoch [2/3], Step [1389/1875], Loss: 0.2857
# Epoch [2/3], Step [1392/1875], Loss: 0.5809
# Epoch [2/3], Step [1395/1875], Loss: 0.3598
# Epoch [2/3], Step [1398/1875], Loss: 0.8859
# Epoch [2/3], Step [1401/1875], Loss: 0.5940
# Epoch [2/3], Step [1404/1875], Loss: 0.6041
# Epoch [2/3], Step [1407/1875], Loss: 0.2196
# Epoch [2/3], Step [1410/1875], Loss: 0.2495
# Epoch [2/3], Step [1413/1875], Loss: 1.0142
# Epoch [2/3], Step [1416/1875], Loss: 0.3325
# Epoch [2/3], Step [1419/1875], Loss: 0.6201
# Epoch [2/3], Step [1422/1875], Loss: 0.4008
# Epoch [2/3], Step [1425/1875], Loss: 0.3504
# Epoch [2/3], Step [1428/1875], Loss: 0.5581
# Epoch [2/3], Step [1431/1875], Loss: 0.3585
# Epoch [2/3], Step [1434/1875], Loss: 0.4056
# Epoch [2/3], Step [1437/1875], Loss: 0.4552
# Epoch [2/3], Step [1440/1875], Loss: 0.2931
# Epoch [2/3], Step [1443/1875], Loss: 0.4805
# Epoch [2/3], Step [1446/1875], Loss: 0.3373
# ...
# Epoch [3/3], Step [783/1875], Loss: 0.4710
# Epoch [3/3], Step [786/1875], Loss: 0.5631
# Epoch [3/3], Step [789/1875], Loss: 0.3339
# Epoch [3/3], Step [792/1875], Loss: 0.6168
# Epoch [3/3], Step [795/1875], Loss: 0.4673
# Epoch [3/3], Step [798/1875], Loss: 0.5272
# Epoch [3/3], Step [801/1875], Loss: 0.4588
# Epoch [3/3], Step [804/1875], Loss: 0.3945
# Epoch [3/3], Step [807/1875], Loss: 0.4234
# Epoch [3/3], Step [810/1875], Loss: 0.7795
# Epoch [3/3], Step [813/1875], Loss: 0.2812
# Epoch [3/3], Step [816/1875], Loss: 0.4725
# Epoch [3/3], Step [819/1875], Loss: 0.2619
# Epoch [3/3], Step [822/1875], Loss: 0.3014
# Epoch [3/3], Step [825/1875], Loss: 0.3863
# Epoch [3/3], Step [828/1875], Loss: 0.2750
# Epoch [3/3], Step [831/1875], Loss: 0.4134
# Epoch [3/3], Step [834/1875], Loss: 0.3386
# Epoch [3/3], Step [837/1875], Loss: 0.4773
# Epoch [3/3], Step [840/1875], Loss: 0.7232
# Epoch [3/3], Step [843/1875], Loss: 0.4227
# Epoch [3/3], Step [846/1875], Loss: 0.7808
# Epoch [3/3], Step [849/1875], Loss: 0.2883
# Epoch [3/3], Step [852/1875], Loss: 0.6554
# Epoch [3/3], Step [855/1875], Loss: 0.3624
# Epoch [3/3], Step [858/1875], Loss: 0.7660
# Epoch [3/3], Step [861/1875], Loss: 0.5929
# Epoch [3/3], Step [864/1875], Loss: 0.2046
# Epoch [3/3], Step [867/1875], Loss: 0.4280
# Epoch [3/3], Step [870/1875], Loss: 0.6084
# Epoch [3/3], Step [873/1875], Loss: 0.3537
# Epoch [3/3], Step [876/1875], Loss: 0.5491
# Epoch [3/3], Step [879/1875], Loss: 0.5329
# Epoch [3/3], Step [882/1875], Loss: 0.2097
# Epoch [3/3], Step [885/1875], Loss: 0.4079
# Epoch [3/3], Step [888/1875], Loss: 0.2854
# Epoch [3/3], Step [891/1875], Loss: 0.4318
# Epoch [3/3], Step [894/1875], Loss: 0.3681
# Epoch [3/3], Step [897/1875], Loss: 0.3428
# Epoch [3/3], Step [900/1875], Loss: 0.6076
# Epoch [3/3], Step [903/1875], Loss: 0.3492
# Epoch [3/3], Step [906/1875], Loss: 0.1632
# Epoch [3/3], Step [909/1875], Loss: 0.2237
# Epoch [3/3], Step [912/1875], Loss: 0.4668
# Epoch [3/3], Step [915/1875], Loss: 0.4875
# Epoch [3/3], Step [918/1875], Loss: 0.6399
# Epoch [3/3], Step [921/1875], Loss: 0.4426
# Epoch [3/3], Step [924/1875], Loss: 0.3603
# Epoch [3/3], Step [927/1875], Loss: 0.2005
# Epoch [3/3], Step [930/1875], Loss: 0.7811
# Epoch [3/3], Step [933/1875], Loss: 0.6576
# Epoch [3/3], Step [936/1875], Loss: 0.5641
# Epoch [3/3], Step [939/1875], Loss: 0.4154
# Epoch [3/3], Step [942/1875], Loss: 0.4686
# Epoch [3/3], Step [945/1875], Loss: 0.4179
# Epoch [3/3], Step [948/1875], Loss: 0.4291
# Epoch [3/3], Step [951/1875], Loss: 0.1967
# Epoch [3/3], Step [954/1875], Loss: 0.3625
# Epoch [3/3], Step [957/1875], Loss: 0.2376
# Epoch [3/3], Step [960/1875], Loss: 0.3475
# Epoch [3/3], Step [963/1875], Loss: 0.3234
# Epoch [3/3], Step [966/1875], Loss: 0.7175
# Epoch [3/3], Step [969/1875], Loss: 0.5838
# Epoch [3/3], Step [972/1875], Loss: 0.8580
# Epoch [3/3], Step [975/1875], Loss: 0.5698
# Epoch [3/3], Step [978/1875], Loss: 0.8386
# Epoch [3/3], Step [981/1875], Loss: 0.3655
# Epoch [3/3], Step [984/1875], Loss: 0.3217
# Epoch [3/3], Step [987/1875], Loss: 0.4981
# Epoch [3/3], Step [990/1875], Loss: 0.4516
# Epoch [3/3], Step [993/1875], Loss: 0.7925
# Epoch [3/3], Step [996/1875], Loss: 0.5463
# Epoch [3/3], Step [999/1875], Loss: 0.4666
# Epoch [3/3], Step [1002/1875], Loss: 0.5465
# Epoch [3/3], Step [1005/1875], Loss: 0.3855
# Epoch [3/3], Step [1008/1875], Loss: 0.4204
# Epoch [3/3], Step [1011/1875], Loss: 0.4066
# Epoch [3/3], Step [1014/1875], Loss: 0.2932
# Epoch [3/3], Step [1017/1875], Loss: 0.3856
# Epoch [3/3], Step [1020/1875], Loss: 0.3028
# Epoch [3/3], Step [1023/1875], Loss: 0.2216
# Epoch [3/3], Step [1026/1875], Loss: 0.2902
# Epoch [3/3], Step [1029/1875], Loss: 0.3309
# Epoch [3/3], Step [1032/1875], Loss: 0.4202
# Epoch [3/3], Step [1035/1875], Loss: 0.6107
# Epoch [3/3], Step [1038/1875], Loss: 0.3670
# Epoch [3/3], Step [1041/1875], Loss: 0.4418
# Epoch [3/3], Step [1044/1875], Loss: 0.3106
# Epoch [3/3], Step [1047/1875], Loss: 0.4198
# Epoch [3/3], Step [1533/1875], Loss: 0.5988
# Epoch [3/3], Step [1536/1875], Loss: 0.3207
# Epoch [3/3], Step [1539/1875], Loss: 0.4541
# Epoch [3/3], Step [1542/1875], Loss: 0.6686
# Epoch [3/3], Step [1545/1875], Loss: 0.4369
# Epoch [3/3], Step [1548/1875], Loss: 0.4941
# Epoch [3/3], Step [1551/1875], Loss: 0.5868
# Epoch [3/3], Step [1554/1875], Loss: 0.5300
# Epoch [3/3], Step [1557/1875], Loss: 0.2226
# Epoch [3/3], Step [1560/1875], Loss: 0.3012
# Epoch [3/3], Step [1563/1875], Loss: 0.7836
# Epoch [3/3], Step [1566/1875], Loss: 0.4176
# Epoch [3/3], Step [1569/1875], Loss: 0.3238
# Epoch [3/3], Step [1572/1875], Loss: 0.3023
# Epoch [3/3], Step [1575/1875], Loss: 0.3616
# Epoch [3/3], Step [1578/1875], Loss: 0.4046
# Epoch [3/3], Step [1581/1875], Loss: 0.4019
# Epoch [3/3], Step [1584/1875], Loss: 0.3389
# Epoch [3/3], Step [1587/1875], Loss: 0.4357
# Epoch [3/3], Step [1590/1875], Loss: 0.4722
# Epoch [3/3], Step [1593/1875], Loss: 0.3419
# Epoch [3/3], Step [1596/1875], Loss: 0.4456
# Epoch [3/3], Step [1599/1875], Loss: 0.2568
# Epoch [3/3], Step [1602/1875], Loss: 0.5732
# Epoch [3/3], Step [1605/1875], Loss: 0.5313
# Epoch [3/3], Step [1608/1875], Loss: 0.4041
# Epoch [3/3], Step [1611/1875], Loss: 0.4240
# Epoch [3/3], Step [1614/1875], Loss: 0.6564
# Epoch [3/3], Step [1617/1875], Loss: 0.3332
# Epoch [3/3], Step [1620/1875], Loss: 0.4964
# Epoch [3/3], Step [1623/1875], Loss: 0.5391
# Epoch [3/3], Step [1626/1875], Loss: 0.2706
# Epoch [3/3], Step [1629/1875], Loss: 0.4259
# Epoch [3/3], Step [1632/1875], Loss: 0.7107
# Epoch [3/3], Step [1635/1875], Loss: 0.3871
# Epoch [3/3], Step [1638/1875], Loss: 0.7069
# Epoch [3/3], Step [1641/1875], Loss: 0.3257
# Epoch [3/3], Step [1644/1875], Loss: 0.2478
# Epoch [3/3], Step [1647/1875], Loss: 0.4142
# Epoch [3/3], Step [1650/1875], Loss: 0.2650
# Epoch [3/3], Step [1653/1875], Loss: 0.5122
# Epoch [3/3], Step [1656/1875], Loss: 0.3830
# Epoch [3/3], Step [1659/1875], Loss: 0.3893
# Epoch [3/3], Step [1662/1875], Loss: 0.3634
# Epoch [3/3], Step [1665/1875], Loss: 0.7013
# Epoch [3/3], Step [1668/1875], Loss: 0.3596
# Epoch [3/3], Step [1671/1875], Loss: 0.3750
# Epoch [3/3], Step [1674/1875], Loss: 0.5775
# Epoch [3/3], Step [1677/1875], Loss: 0.5116
# Epoch [3/3], Step [1680/1875], Loss: 0.4794
# Epoch [3/3], Step [1683/1875], Loss: 0.1903
# Epoch [3/3], Step [1686/1875], Loss: 0.3979
# Epoch [3/3], Step [1689/1875], Loss: 0.3421
# Epoch [3/3], Step [1854/1875], Loss: 0.5103
# Epoch [3/3], Step [1857/1875], Loss: 0.2714
# Epoch [3/3], Step [1860/1875], Loss: 0.3154
# Epoch [3/3], Step [1863/1875], Loss: 0.5672
# Epoch [3/3], Step [1866/1875], Loss: 0.3839
# Epoch [3/3], Step [1869/1875], Loss: 0.5145
# Epoch [3/3], Step [1872/1875], Loss: 0.4528
# Epoch [3/3], Step [1875/1875], Loss: 0.4665

# %%
# EX 7 HW
# Finish the training loop instructions

# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training times)
epochs = 3

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    ### Training
    train_loss = 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):
        model_0.train()
        # 1. Forward pass
        y_pred = model_0(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 400 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy
    test_loss, test_acc = 0, 0
    model_0.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:
            # 1. Forward pass
            test_pred = model_0(X)

            # 2. Calculate loss (accumatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculations on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by length of test dataloader (per batch)
        test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")



# Calculate training time
train_time_end_on_cpu = timer()
total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu,
                                           end=train_time_end_on_cpu)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.44165, Test acc: 84.82%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.43071, Test acc: 85.28%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.43846, Test acc: 85.06%
#
# Train time on None: 29.816 seconds

# %%
#EVALUATE BAS EMODEL

# %%
torch.manual_seed(42)
def eval_model(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               accuracy_fn):
    """Returns a dictionary containing the results of model predicting on data_loader.

    Args:
        model (torch.nn.Module): A PyTorch model capable of making predictions on data_loader.
        data_loader (torch.utils.data.DataLoader): The target dataset to predict on.
        loss_fn (torch.nn.Module): The loss function of model.
        accuracy_fn: An accuracy function to compare the models predictions to the truth labels.

    Returns:
        (dict): Results of model making predictions on data_loader.
    """
    loss, acc = 0, 0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            y_pred = model(X)

            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
            acc += accuracy_fn(y_true=y,
                                y_pred=y_pred.argmax(dim=1)) # For accuracy, need the prediction labels (logits -> pred_prob -> pred_labels)

        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        acc /= len(data_loader)

    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item(),
            "model_acc": acc}

# Calculate model 0 results on test dataset
model_0_results = eval_model(model=model_0, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn
)
model_0_results
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.4384560286998749,
#  'model_acc': 85.06389776357827}

# %%
import torch
from torch import nn

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Define the model class with non-linearities
class FashionMNISTModelV1(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()

        #EX 9 START
        self.layer_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, hidden_units),
            nn.ReLU(),
            nn.Linear(hidden_units, output_shape),
            nn.ReLU()
        )
        #EX 9 END

    def forward(self, x):
        return self.layer_stack(x)

# Recreate the model with non-linearities
torch.manual_seed(42)
model_1 = FashionMNISTModelV1(input_shape=784,  # number of input features
                              hidden_units=10,
                              output_shape=len(class_names)).to(device)  # send model to GPU if available

# Check model device
next(model_1.parameters()).device
# Out:
# device(type='cpu')

# %%
# Task 10 Create the same loss + Optimizer as for V0

## Make sure to use after the for loop if you are using a gpu
# Send data to GPU
# X, y = X.to(device), y.to(device)


# Task 10 Create the same loss + Optimizer as for V0

loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.1)

# %%
# Task 11 Train And Test it as before

# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training times)
epochs = 3

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    ### Training
    train_loss = 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):
        X, y = X.to(device), y.to(device)
        model_1.train()
        # 1. Forward pass
        y_pred = model_1(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 400 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy
    test_loss, test_acc = 0, 0
    model_1.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:
            # 1. Forward pass
            test_pred = model_1(X)

            # 2. Calculate loss (accumatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculations on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by length of test dataloader (per batch)
        test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")



# Calculate training time
train_time_end_on_cpu = timer()
total_train_time_model_1 = print_train_time(start=train_time_start_on_cpu,
                                           end=train_time_end_on_cpu)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.95636, Test acc: 65.00%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.72227, Test acc: 73.91%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.68500, Test acc: 75.02%
#
# Train time on None: 32.346 seconds

# %%
# Convulational Neural Network


# Setup device agnostic code
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device





torch.manual_seed(42)

# Create sample batch of random numbers with same size as image batch
images = torch.randn(size=(32, 3, 64, 64)) # [batch_size, color_channels, height, width]
test_image = images[0] # get a single image for testing



torch.manual_seed(42)

# Create a convolutional layer with same dimensions as TinyVGG
# (try changing any of the parameters and see what happens)
conv_layer = nn.Conv2d(in_channels=3,
                       out_channels=10,
                       kernel_size=3,
                       stride=1,
                       padding=0) # also try using "valid" or "same" here

# Pass the data through the convolutional layer
conv_layer(test_image) # Note: If running PyTorch <1.11.0, this will error because of shape issues (nn.Conv.2d() expects a 4d tensor as input)
# Out:
# tensor([[[ 1.5396,  0.0516,  0.6454,  ..., -0.3673,  0.8711,  0.4256],
#          [ 0.3662,  1.0114, -0.5997,  ...,  0.8983,  0.2809, -0.2741],
#          [ 1.2664, -1.4054,  0.3727,  ..., -0.3409,  1.2191, -0.0463],
#          ...,
#          [-0.1541,  0.5132, -0.3624,  ..., -0.2360, -0.4609, -0.0035],
#          [ 0.2981, -0.2432,  1.5012,  ..., -0.6289, -0.7283, -0.5767],
#          [-0.0386, -0.0781, -0.0388,  ...,  0.2842,  0.4228, -0.1802]],
#
#         [[-0.2840, -0.0319, -0.4455,  ..., -0.7956,  1.5599, -1.2449],
#          [ 0.2753, -0.1262, -0.6541,  ..., -0.2211,  0.1999, -0.8856],
#          [-0.5404, -1.5489,  0.0249,  ..., -0.5932, -1.0913, -0.3849],
#          ...,
#          [ 0.3870, -0.4064, -0.8236,  ...,  0.1734, -0.4330, -0.4951],
#          [-0.1984, -0.6386,  1.0263,  ..., -0.9401, -0.0585, -0.7833],
#          [-0.6306, -0.2052, -0.3694,  ..., -1.3248,  0.2456, -0.7134]],
#
#         [[ 0.4414,  0.5100,  0.4846,  ..., -0.8484,  0.2638,  1.1258],
#          [ 0.8117,  0.3191, -0.0157,  ...,  1.2686,  0.2319,  0.5003],
#          [ 0.3212,  0.0485, -0.2581,  ...,  0.2258,  0.2587, -0.8804],
#          ...,
#          [-0.1144, -0.1869,  0.0160,  ..., -0.8346,  0.0974,  0.8421],
#          [ 0.2941,  0.4417,  0.5866,  ..., -0.1224,  0.4814, -0.4799],
#          [ 0.6059, -0.0415, -0.2028,  ...,  0.1170,  0.2521, -0.4372]],
#
#         ...,
#
#         [[-0.2560, -0.0477,  0.6380,  ...,  0.6436,  0.7553, -0.7055],
#          [ 1.5595, -0.2209, -0.9486,  ..., -0.4876,  0.7754,  0.0750],
#          [-0.0797,  0.2471,  1.1300,  ...,  0.1505,  0.2354,  0.9576],
#          ...,
#          [ 1.1065,  0.6839,  1.2183,  ...,  0.3015, -0.1910, -0.1902],
#          [-0.3486, -0.7173, -0.3582,  ...,  0.4917,  0.7219,  0.1513],
#          [ 0.0119,  0.1017,  0.7839,  ..., -0.3752, -0.8127, -0.1257]],
#
#         [[ 0.3841,  1.1322,  0.1620,  ...,  0.7010,  0.0109,  0.6058],
#          [ 0.1664,  0.1873,  1.5924,  ...,  0.3733,  0.9096, -0.5399],
#          [ 0.4094, -0.0861, -0.7935,  ..., -0.1285, -0.9932, -0.3013],
#          ...,
#          [ 0.2688, -0.5630, -1.1902,  ...,  0.4493,  0.5404, -0.0103],
#          [ 0.0535,  0.4411,  0.5313,  ...,  0.0148, -1.0056,  0.3759],
#          [ 0.3031, -0.1590, -0.1316,  ..., -0.5384, -0.4271, -0.4876]],
#
#         [[-1.1865, -0.7280, -1.2331,  ..., -0.9013, -0.0542, -1.5949],
#          [-0.6345, -0.5920,  0.5326,  ..., -1.0395, -0.7963, -0.0647],
#          [-0.1132,  0.5166,  0.2569,  ...,  0.5595, -1.6881,  0.9485],
#          ...,
#          [-0.0254, -0.2669,  0.1927,  ..., -0.2917,  0.1088, -0.4807],
#          [-0.2609, -0.2328,  0.1404,  ..., -0.1325, -0.8436, -0.7524],
#          [-1.1399, -0.1751, -0.8705,  ...,  0.1589,  0.3377,  0.3493]]],
#        grad_fn=<SqueezeBackward1>)

# %%
# EXTRA EX: kernel size
# Create a convolutional neural network
class FashionMNISTModelV2(nn.Module):
    """
    Model architecture copying TinyVGG from:
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1),# options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from?
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*7*7,
                      out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

torch.manual_seed(42)
model_2 = FashionMNISTModelV2(input_shape=1,
    hidden_units=10,
    output_shape=len(class_names)).to(device)
print(model_2)
# Out:
# FashionMNISTModelV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %%
# POOLING
import torch
import torch.nn as nn

# Create a random 2D tensor of shape (1, 1, 4, 4)
input_tensor = torch.rand(1, 1, 4, 4)

# Define a max pooling layer with a kernel size of (2, 2)
maxpool_layer = nn.MaxPool2d(kernel_size=(2, 2))

# Apply the max pooling layer to the input tensor
output_tensor = maxpool_layer(input_tensor)

# Print the input and output tensor shapes
print("Input shape:", input_tensor.shape)
print("Output shape:", output_tensor.shape)
# Out:
# Input shape: torch.Size([1, 1, 4, 4])
# Output shape: torch.Size([1, 1, 2, 2])

# %%
# Ex 12 Train and evaluate this model
# When training convert output from logits like
    # # Do the forward pass
    # y_logit = model_2(X)
    # # Turn predictions from logits -> prediction probabilities -> predictions labels
    # y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
# Also compare the results(accuracy) and the training time

import torch.optim as optim

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.1) # optim.Adam(model_2.parameters(), lr=0.001)


def train(model, train_loader, optimizer, loss_fn, device):
    model.train()
    train_loss = 0
    train_acc = 0

    for X, y in train_loader:
        X = X.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        y_logit = model(X)

        loss = loss_fn(y_logit, y)
        loss.backward()
        optimizer.step()

        y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
        train_acc += (y_pred == y).sum().item()
        train_loss += loss.item()

    train_loss /= len(train_loader.dataset)
    train_acc /= len(train_loader.dataset)
    return train_loss, train_acc


def evaluate(model, test_loader, loss_fn, device):
    model.eval()
    test_loss = 0
    test_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)

            y_logit = model(X)
            loss = loss_fn(y_logit, y)

            y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
            test_acc += (y_pred == y).sum().item()
            test_loss += loss.item()

    test_loss /= len(test_loader.dataset)
    test_acc /= len(test_loader.dataset)
    return test_loss, test_acc

# %%
import time

num_epochs = 5

for epoch in range(num_epochs):
    start_time = time.time()

    train_loss, train_acc = train(model_2, train_dataloader, optimizer, loss_fn, device)
    test_loss, test_acc = evaluate(model_2, test_dataloader, loss_fn, device)

    end_time = time.time()
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Time: {end_time - start_time:.2f}s")
# Out:
# Epoch 1/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 56.00s
# Epoch 2/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 50.79s
# Epoch 3/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 51.97s
# Epoch 4/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 50.53s
# Epoch 5/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 53.71s
